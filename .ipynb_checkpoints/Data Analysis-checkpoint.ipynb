# %%
import json
file = open("hn_2014.json")
hn = json.load(file)

print(type(hn))
# Out:
# <class 'list'>

# %% [markdown]
# Let's find out how many objects are in the list, and the type of the first object

# %%
print(len(hn))
print(type(hn[0]))
# Out:
# 35806
# <class 'dict'>

# %% [markdown]
# Our data set contains 35,806 dictionary objects, each representing a Hacker News story. Let's look at some keys from the dictionary.

# %%
hn[0].keys()
# Out:
# dict_keys(['author', 'numComments', 'points', 'url', 'storyText', 'createdAt', 'tags', 'createdAtI', 'title', 'objectId'])

# %%
hn[0]["title"]
# Out:
# 'Are we getting too Sassy? Weighing up micro-optimisation vs. maintainability'

# %%
def del_key(dict_, key):
    # create a copy so we don't
    # modify the original dict
    modified_dict = dict_.copy()
    del modified_dict[key]
    return modified_dict

# %%
hn_clean = [del_key(d, 'createdAtI') for d in hn]
for i in range(0,3):
    print(hn_clean[i],"\n")
# Out:
# {'author': 'dragongraphics', 'numComments': 0, 'points': 2, 'url': 'http://ashleynolan.co.uk/blog/are-we-getting-too-sassy', 'storyText': '', 'createdAt': '2014-05-29T08:07:50Z', 'tags': ['story', 'author_dragongraphics', 'story_7815238'], 'title': 'Are we getting too Sassy? Weighing up micro-optimisation vs. maintainability', 'objectId': '7815238'}
#
# {'author': 'jcr', 'numComments': 0, 'points': 1, 'url': 'http://spectrum.ieee.org/automaton/robotics/home-robots/telemba-telepresence-robot', 'storyText': '', 'createdAt': '2014-05-29T08:05:58Z', 'tags': ['story', 'author_jcr', 'story_7815234'], 'title': 'Telemba Turns Your Old Roomba and Tablet Into a Telepresence Robot', 'objectId': '7815234'}
#
# {'author': 'callum85', 'numComments': 0, 'points': 1, 'url': 'http://online.wsj.com/articles/apple-to-buy-beats-1401308971', 'storyText': '', 'createdAt': '2014-05-29T08:05:06Z', 'tags': ['story', 'author_callum85', 'story_7815230'], 'title': 'Apple Agrees to Buy Beats for $3 Billion', 'objectId': '7815230'}

# %% [markdown]
# Let us extract the url value from each dictionary in hn_clean

# %%
urls = [item["url"] for item in hn_clean]
for i in range(0,5):
    print(urls[i])
# Out:
# http://ashleynolan.co.uk/blog/are-we-getting-too-sassy
# http://spectrum.ieee.org/automaton/robotics/home-robots/telemba-telepresence-robot
# http://online.wsj.com/articles/apple-to-buy-beats-1401308971
# http://alexsblog.org/2014/05/29/dont-wait-for-inspiration/
# http://techcrunch.com/2014/05/28/hackerone-get-9m-in-series-a-funding-to-build-bug-tracking-bounty-programs/

# %% [markdown]
# Let's count the number of stories that have comments. Note that column "numComments" in hn_clean is an integer, with 0 if there are no comments.

# %%
has_comments = [d for d in hn_clean if d["numComments"]>0]
for i in range(10):
    print(has_comments[i]["title"])
# Out:
# Five Super Successful Tech Pivots
# Gi Bike: The light, full-size, electric, folding bike
# For Hire: Dedicated Young Man With Down Syndrome
# World War II in the Pacific, narrated by my grandpa
# The NSA can't remotely turn on all phones
# Chrome Logger
# My Response to the Accusation that Nerds are Misogynistic
# Microsoft Lays out the Future of Internet Explorer
# The Soylent Revolution Will Not Be Pleasurable
# Pure 0.5.0 – Get Started with Grids

# %%
print(len(has_comments), " total titles with at least one comment")
# Out:
# 9279  total titles with at least one comment

# %% [markdown]
# Let's count how many stories have more than 1000 points and display their titles.

# %%
thousand_points = [d for d in hn_clean if d["points"]>1000]
num_thousand_points = len(thousand_points)
print(num_thousand_points)
# Out:
# 8

# %%
for row in thousand_points:
    print(row["points"], " points", ": ", row["title"])
# Out:
# 1297  points :  Microsoft Open Sources C# Compiler
# 1192  points :  Elon Musk: To the People of New Jersey
# 2732  points :  2048
# 1095  points :  The Face Behind Bitcoin?
# 1054  points :  Facebook Buying WhatsApp for $16B in Cash and Stock Plus $3B in RSUs
# 1958  points :  Today is The Day We Fight Back
# 1062  points :  Mystery signal from a helicopter
# 1522  points :  Wozniak: “Actually, the movie was largely a lie about me”

# %% [markdown]
# Let's find the story that has the greatest number of comments. First let's write a small function to help print json objects nicely.

# %%
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# %%
def key_function(json_dict):
    return json_dict["numComments"]

most_comments = max(hn_clean, key=key_function)

jprint(most_comments)
# Out:
# {
#     "author": "platz",
#     "createdAt": "2014-04-03T19:02:53Z",
#     "numComments": 1208,
#     "objectId": "7525198",
#     "points": 889,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_platz",
#         "story_7525198"
#     ],
#     "title": "Brendan Eich Steps Down as Mozilla CEO",
#     "url": "https://blog.mozilla.org/blog/2014/04/03/brendan-eich-steps-down-as-mozilla-ceo/"
# }

# %% [markdown]
# Next let us sort the items in our JSON list alphabetically by name

# %%
temp = sorted(hn_clean, key=lambda x: x["author"])
print(len(temp))
for i in range(0,35806,250):
    jprint(temp[i])
# Out:
# 35806
# {
#     "author": "001sky",
#     "createdAt": "2014-05-28T10:24:46Z",
#     "numComments": 1,
#     "objectId": "7809196",
#     "points": 1,
#     "storyText": "see also: S&amp;P Assigns &#x27;B-&#x27; Rating to Tesla (TSLA); Notes &#x27;Vulnerable&#x27; Business Risk Profile<p>http:&#x2F;&#x2F;www.streetinsider.com&#x2F;Credit+Ratings&#x2F;S%26P+Assigns+B-+Rating+to+Tesla+%28TSLA%29%3B+Notes+Vulnerable+Business+Risk+Profile&#x2F;9525763.html",
#     "tags": [
#         "story",
#         "author_001sky",
#         "story_7809196"
#     ],
#     "title": "S&P Rates Tesla Debt as 'Junk' \u2013 Update",
#     "url": "http://online.wsj.com/article/BT-CO-20140527-712847.html"
# }
# {
#     "author": "ALee",
#     "createdAt": "2014-02-23T02:09:00Z",
#     "numComments": 0,
#     "objectId": "7284623",
#     "points": 3,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_ALee",
#         "story_7284623"
#     ],
#     "title": "Uber and Lyft plan Houston invasion by offering services for free",
#     "url": "http://houston.culturemap.com/news/city-life/02-20-14-uber-and-lyft-plan-houston-invasion-by-offering-car-calling-app-services-for-free"
# }
# {
#     "author": "AndyBaker",
#     "createdAt": "2014-03-24T11:16:17Z",
#     "numComments": 0,
#     "objectId": "7457614",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_AndyBaker",
#         "story_7457614"
#     ],
#     "title": "K-Server Problem",
#     "url": "http://en.wikipedia.org/wiki/K-server_problem"
# }
# {
#     "author": "Bogdins",
#     "createdAt": "2014-04-27T11:17:57Z",
#     "numComments": 0,
#     "objectId": "7654689",
#     "points": 1,
#     "storyText": "The next shopping platform is the missing step between existing e-commerce systems and (far from now) implementation of augmented reality desired experience.\\nWith my new shopping platform, several issues will be achieved:\\n- increased sales volume: because my concept take advantage of human behavior (seeing is shopping);\\n- ads powered but avoiding to be annoying;\\n- best user experience and user interface ever designed;\\n- comprehensive product information for better selection;\\n- powerful social-commerce integration.",
#     "tags": [
#         "story",
#         "author_Bogdins",
#         "story_7654689"
#     ],
#     "title": "The next shopping platform",
#     "url": ""
# }
# {
#     "author": "ColinWright",
#     "createdAt": "2014-05-17T19:17:46Z",
#     "numComments": 27,
#     "objectId": "7760794",
#     "points": 48,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_ColinWright",
#         "story_7760794"
#     ],
#     "title": "Algorithm appointed board director",
#     "url": "http://www.bbc.com/news/technology-27426942?HN2"
# }
# {
#     "author": "DanielRibeiro",
#     "createdAt": "2014-04-20T01:04:21Z",
#     "numComments": 0,
#     "objectId": "7615366",
#     "points": 2,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_DanielRibeiro",
#         "story_7615366"
#     ],
#     "title": "Bears On Stairs: stop motion animation of 3D printed pieces",
#     "url": "http://petapixel.com/2014/04/15/bears-stairs-ridiculously-smooth-stop-motion-animated-video/"
# }
# {
#     "author": "Epicster",
#     "createdAt": "2014-02-25T19:07:26Z",
#     "numComments": 0,
#     "objectId": "7299696",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_Epicster",
#         "story_7299696"
#     ],
#     "title": "How to Find Business Ideas \u2013 The Ultimate Guide",
#     "url": "http://www.epicster.com/start-your-own-business-ideas/"
# }
# {
#     "author": "Golddisk",
#     "createdAt": "2014-03-14T18:02:03Z",
#     "numComments": 0,
#     "objectId": "7400637",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_Golddisk",
#         "story_7400637"
#     ],
#     "title": "Could The Malaysia Airlines Missing Jet Be An Act Of Piracy?",
#     "url": "http://thesurge.net/could-the-malaysia-airlines-missing-jet-be-an-act-of-piracy/"
# }
# {
#     "author": "Jamie452",
#     "createdAt": "2014-03-29T21:28:14Z",
#     "numComments": 1,
#     "objectId": "7494043",
#     "points": 1,
#     "storyText": "Just wanted to get some early feedback - this is my university project and is nowhere near finished yet!<p>Works best in Chrome, FireFox works too but does have a few bugs!<p>Keen to hear your thoughts!",
#     "tags": [
#         "story",
#         "author_Jamie452",
#         "story_7494043",
#         "show_hn"
#     ],
#     "title": "Show HN: FastWoo (Early Beta) \u2013 WebRTC social network based around interests",
#     "url": "http://www.fastwoo.com/guest-home"
# }
# {
#     "author": "KhalilK",
#     "createdAt": "2014-03-19T10:57:47Z",
#     "numComments": 0,
#     "objectId": "7427797",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_KhalilK",
#         "story_7427797"
#     ],
#     "title": "Google Takes The Chromecast Beyond The U.S. \u2013 To 11 Markets In Europe and Canada",
#     "url": "http://techcrunch.com/2014/03/19/chromecast-goes-to-europe/"
# }
# {
#     "author": "MaciejCzyzewski",
#     "createdAt": "2014-01-18T16:45:56Z",
#     "numComments": 0,
#     "objectId": "7081349",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_MaciejCzyzewski",
#         "story_7081349"
#     ],
#     "title": "Bottomline - utility library in PHP",
#     "url": "http://maciejczyzewski.github.io/Bottomline"
# }
# {
#     "author": "MrZongle2",
#     "createdAt": "2014-03-14T20:07:53Z",
#     "numComments": 2,
#     "objectId": "7401467",
#     "points": 6,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_MrZongle2",
#         "story_7401467"
#     ],
#     "title": "Russia claims to have intercepted US drone over Crimea",
#     "url": "http://news.yahoo.com/russia-says-intercepted-us-drone-over-crimea-arms-180430584.html"
# }
# {
#     "author": "Protostome",
#     "createdAt": "2014-01-07T07:13:31Z",
#     "numComments": 4,
#     "objectId": "7016111",
#     "points": 3,
#     "storyText": "Hello everyone,<p>I&#x27;m here to share my frustration :)<p>Few weeks ago we met a CEO of a major company that had interest in our product.<p>He was really excited to work with us - up till the moment he heard we haven&#x27;t developed an IOS version of our product yet.<p>The meeting ended when he said to us something like: &quot;I&#x27;ll be glad to work with you, but only when you have both Android and IOS versions.&quot;<p>So, after a short discussion we made a small pivot and started developing the product almost from scratch - with PhoneGap. (Not such a big deal since most of the logic reside on the server anyway).<p>Now although the app is relatively basic in terms of graphics, it feels a little sluggish and slow to respond.<p>So we were left with a dilemma - would you make a compromise about the quality of the product just to get a first major customer you would love to have on your porfolio?",
#     "tags": [
#         "story",
#         "author_Protostome",
#         "story_7016111",
#         "ask_hn"
#     ],
#     "title": "Ask HN: Should we degrade our product to get a first, major customer?",
#     "url": ""
# }
# {
#     "author": "RougeFemme",
#     "createdAt": "2014-01-24T01:31:42Z",
#     "numComments": 0,
#     "objectId": "7112822",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_RougeFemme",
#         "story_7112822"
#     ],
#     "title": "Startup Post-Mortems Offer All Sorts Of Surprising Lessons",
#     "url": "http://www.fastcolabs.com/3025381/startup-post-mortems-offer-all-sorts-of-surprising-lessons"
# }
# {
#     "author": "SmokinRook",
#     "createdAt": "2014-02-10T18:21:32Z",
#     "numComments": 0,
#     "objectId": "7212661",
#     "points": 3,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_SmokinRook",
#         "story_7212661"
#     ],
#     "title": "Why would any mobile developer walk away from $50k a day?",
#     "url": "http://slashdot.org/topic/cloud/the-mystery-of-flappy-bird/"
# }
# {
#     "author": "Tiktaalik",
#     "createdAt": "2014-01-30T06:09:49Z",
#     "numComments": 0,
#     "objectId": "7149295",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_Tiktaalik",
#         "story_7149295"
#     ],
#     "title": "Apple's $3 Trillion Valuation",
#     "url": "http://www.jayhaynes.net/2014/01/apples-3-trillion-valuation.html"
# }
# {
#     "author": "Wezc",
#     "createdAt": "2014-01-21T21:23:07Z",
#     "numComments": 15,
#     "objectId": "7098500",
#     "points": 16,
#     "storyText": "Bonjour HN !<p>I am a 20 year-old French CS&#x2F;IT student at EPITECH Rennes, France (European Institute of Technology, www.epitech.eu) class 2016. As a third year student in a 5-year combined Bachelor-Master&#x27;s program, I study full-time and currently have part-time employment at a French games and mobile applications development studio (native app on Android and iOS).<p>My study offer me the opportunity to perform a full-time internship up to 7 months. From March to September 2014 before joining CSU Long beach and UC Berkeley to study next year.\\nDynamic and polyvalent, I am curious and have been interested in information technology since my childhood. I chose not to wait to join an high technical school to be trained in coding, which I love, and have continuously tried to improve my skills through self-study.\\nWith a strong background in software development and project managing (either in system, web or mobile domain), I am highly motivated by the perspective of joining great teams, participate and build amazing services by making available and share my experiences and skills to your company.<p>Key skills: C (UNIX), C++, C#.NET, Objective-C (Cocoa-touch), Java (J2EE, Android), Python, PHP, OCaml, JavaScript (Node.js), SQL, HTML&#x2F;CSS, VBA, Shell scripting, MySQL, MongoDB.\\nAnd I am currently learning Go!<p>I believe that I will be a good fit for an intern software engineering&#x2F;development position. If you are not hiring for such a position, do not hesitate to spread the word around you ! I&#x27;ll get my master in 2016 so maybe we can get in touch right now regarding my futures availabilities.<p>Thank you so much for reading ! I hope to have caught your attention :)\\nI am listening to any comment you may have ! Feel free to drop me a line here or via email: julien.fortin@epitech.eu<p>http:&#x2F;&#x2F;www.fever42.com&#x2F; See my links below.<p>Please upvote and share :)\\nMerci !",
#     "tags": [
#         "story",
#         "author_Wezc",
#         "story_7098500",
#         "ask_hn"
#     ],
#     "title": "Ask HN: French software engineering student, looking for a nobullshit internship",
#     "url": ""
# }
# {
#     "author": "a_olt",
#     "createdAt": "2014-04-29T13:02:55Z",
#     "numComments": 0,
#     "objectId": "7666635",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_a_olt",
#         "story_7666635"
#     ],
#     "title": " Building a gesture-controlled Web game ",
#     "url": "http://arstechnica.com/business/2014/04/building-a-gesture-controlled-web-game-with-leap-motion/"
# }
# {
#     "author": "acangiano",
#     "createdAt": "2014-03-31T16:39:52Z",
#     "numComments": 0,
#     "objectId": "7502508",
#     "points": 1,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_acangiano",
#         "story_7502508"
#     ],
#     "title": "Big Data Vendor Revenue And Market Forecast 2013-2017",
#     "url": "http://wikibon.org/wiki/v/Big_Data_Vendor_Revenue_and_Market_Forecast_2013-2017"
# }
# {
#     "author": "adamsc64",
#     "createdAt": "2014-04-01T15:58:00Z",
#     "numComments": 0,
#     "objectId": "7509240",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_adamsc64",
#         "story_7509240"
#     ],
#     "title": "Etymology of \"Foo\" (RFC 3092)",
#     "url": "http://tools.ietf.org/html/rfc3092"
# }
# {
#     "author": "aet",
#     "createdAt": "2014-05-20T13:25:53Z",
#     "numComments": 0,
#     "objectId": "7772387",
#     "points": 1,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_aet",
#         "story_7772387"
#     ],
#     "title": "How to Have an Honest Data-Driven Debate",
#     "url": "http://blogs.hbr.org/2014/04/how-to-present-statistics-honestly/"
# }
# {
#     "author": "alexandros",
#     "createdAt": "2014-02-25T10:55:23Z",
#     "numComments": 0,
#     "objectId": "7296847",
#     "points": 1,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_alexandros",
#         "story_7296847"
#     ],
#     "title": "A completely non-technical explanation of Linux Containers",
#     "url": "http://resin.io/blog/a-completely-non-technical-explanation-of-linux-containers/"
# }
# {
#     "author": "amazedsaint",
#     "createdAt": "2014-05-04T07:33:09Z",
#     "numComments": 1,
#     "objectId": "7693638",
#     "points": 3,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_amazedsaint",
#         "story_7693638"
#     ],
#     "title": "[NONSENSE ALERT] I-Team: 'Heartbleed virus' a confusing security threat",
#     "url": "http://abclocal.go.com/wls/story?section=news%2Fiteam&id=9521428"
# }
# {
#     "author": "andyanderson",
#     "createdAt": "2014-05-15T22:14:38Z",
#     "numComments": 0,
#     "objectId": "7752575",
#     "points": 1,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_andyanderson",
#         "story_7752575"
#     ],
#     "title": "Jack Dorsey to Employees: Name-Dropping Makes You Look Dumb",
#     "url": "http://entrepreneur.com/article/233939"
# }
# {
#     "author": "antr",
#     "createdAt": "2014-01-29T09:39:23Z",
#     "numComments": 34,
#     "objectId": "7142934",
#     "points": 79,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_antr",
#         "story_7142934"
#     ],
#     "title": "Post mortem: Thanks and lessons learned",
#     "url": "http://elnorr.com/2014/01/27/post-mortem-thanks-lessons-learned/"
# }
# {
#     "author": "arizabu",
#     "createdAt": "2014-01-17T15:31:28Z",
#     "numComments": 0,
#     "objectId": "7076243",
#     "points": 1,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_arizabu",
#         "story_7076243"
#     ],
#     "title": "Yeggi - Printable 3D Models Search Engine",
#     "url": "http://www.yeggi.com/"
# }
# {
#     "author": "atilev",
#     "createdAt": "2014-01-28T12:58:53Z",
#     "numComments": 0,
#     "objectId": "7136771",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_atilev",
#         "story_7136771"
#     ],
#     "title": "Battle of windows cli",
#     "url": "http://jlark20.wordpress.com/2014/01/27/the-battle-of-windows-command-line-interfaces/"
# }
# {
#     "author": "bahoo",
#     "createdAt": "2014-01-31T17:21:58Z",
#     "numComments": 0,
#     "objectId": "7157777",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_bahoo",
#         "story_7157777"
#     ],
#     "title": "How federal agents ended up as the movie industry's copyright enforcers",
#     "url": "http://www.dailydot.com/politics/federal-agents-google-glass-mpaa-theater-enforcers/"
# }
# {
#     "author": "baylinguist",
#     "createdAt": "2014-05-22T14:51:43Z",
#     "numComments": 0,
#     "objectId": "7784133",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_baylinguist",
#         "story_7784133"
#     ],
#     "title": "Getting the most out of Trello project management | Startup best practice",
#     "url": "http://blog.lingohub.com/industry-updates/2014/05/getting-ouf-trello-project-management/"
# }
# {
#     "author": "benologist",
#     "createdAt": "2014-01-24T03:03:12Z",
#     "numComments": 0,
#     "objectId": "7113120",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_benologist",
#         "story_7113120"
#     ],
#     "title": "Candy Jam invites devs to make games using industry's litigious vocabulary",
#     "url": "http://www.joystiq.com/2014/01/22/the-candy-jam-invites-devs-to-make-games-using-the-industrys-li/"
# }
# {
#     "author": "bitops",
#     "createdAt": "2014-02-06T00:09:51Z",
#     "numComments": 1,
#     "objectId": "7187796",
#     "points": 3,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_bitops",
#         "story_7187796"
#     ],
#     "title": "Comcast customer surprised to learn new router is also public hotspot",
#     "url": "http://arstechnica.com/information-technology/2014/02/comcast-customer-surprised-to-learn-new-router-is-also-public-hotspot/"
# }
# {
#     "author": "boitnott",
#     "createdAt": "2014-02-28T23:34:52Z",
#     "numComments": 0,
#     "objectId": "7322276",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_boitnott",
#         "story_7322276"
#     ],
#     "title": "Why Uber Driving Is For Introverts, And Other Ridesharing Tales",
#     "url": "http://www.fastcolabs.com/3027117/why-uber-driving-is-for-introverts-and-other-ridesharing-tales"
# }
# {
#     "author": "brettgoulder",
#     "createdAt": "2014-04-03T03:42:41Z",
#     "numComments": 20,
#     "objectId": "7520806",
#     "points": 28,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_brettgoulder",
#         "story_7520806"
#     ],
#     "title": "Calibre beta announced",
#     "url": "https://calibreapp.com/"
# }
# {
#     "author": "buraksarica",
#     "createdAt": "2014-05-08T11:22:01Z",
#     "numComments": 1,
#     "objectId": "7714714",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_buraksarica",
#         "story_7714714",
#         "show_hn"
#     ],
#     "title": "Show HN: A simple photo-text app TaaP",
#     "url": "https://itunes.apple.com/us/app/taap/id868640714?l=tr&ls=1&mt=8"
# }
# {
#     "author": "carlsednaoui",
#     "createdAt": "2014-03-19T21:28:07Z",
#     "numComments": 0,
#     "objectId": "7432005",
#     "points": 7,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_carlsednaoui",
#         "story_7432005"
#     ],
#     "title": "MailChimp's 404 page",
#     "url": "http://mailchimp.com/404/"
# }
# {
#     "author": "chancancode",
#     "createdAt": "2014-04-17T16:38:10Z",
#     "numComments": 5,
#     "objectId": "7604635",
#     "points": 7,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_chancancode",
#         "story_7604635"
#     ],
#     "title": "Curating Email Newsletters Sucked \u2013 So We Built Goodbits",
#     "url": "http://blog.goodbits.io/2014/04/15/we-built-goodbits"
# }
# {
#     "author": "chmars",
#     "createdAt": "2014-02-26T12:46:13Z",
#     "numComments": 1,
#     "objectId": "7304575",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_chmars",
#         "story_7304575"
#     ],
#     "title": "Updating to 10.9.2 for security reasons, but the biggest backdoor is still there",
#     "url": "http://www.mulle-kybernetik.com/weblog/2014/02/updating-to-1092-for-security.html"
# }
# {
#     "author": "cjrp",
#     "createdAt": "2014-01-21T16:08:29Z",
#     "numComments": 0,
#     "objectId": "7096090",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_cjrp",
#         "story_7096090"
#     ],
#     "title": "Mobile analyst Benedict Evans to join Andreessen Horowitz",
#     "url": "http://ben-evans.com/benedictevans/2014/1/18/a16z"
# }
# {
#     "author": "codecoda",
#     "createdAt": "2014-02-01T06:08:33Z",
#     "numComments": 0,
#     "objectId": "7161020",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_codecoda",
#         "story_7161020"
#     ],
#     "title": "1st 10 Facebook users?",
#     "url": "http://www.theguardian.com/technology/2014/jan/31/who-were-the-first-10-users-on-facebook"
# }
# {
#     "author": "coltr",
#     "createdAt": "2014-03-09T23:42:57Z",
#     "numComments": 0,
#     "objectId": "7370510",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_coltr",
#         "story_7370510"
#     ],
#     "title": "Scientists find new manmade, ozone-depleting gases",
#     "url": "http://cir.ca/s/s6y"
# }
# {
#     "author": "crazy_geek",
#     "createdAt": "2014-04-15T17:03:24Z",
#     "numComments": 0,
#     "objectId": "7592940",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_crazy_geek",
#         "story_7592940"
#     ],
#     "title": "Refactoring Flow Control And Conditionals",
#     "url": "http://drew.thecsillags.com/posts/refactoring-flow-control-and-conditionals.html"
# }
# {
#     "author": "cybernewsalerts",
#     "createdAt": "2014-02-02T06:33:24Z",
#     "numComments": 0,
#     "objectId": "7165131",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_cybernewsalerts",
#         "story_7165131"
#     ],
#     "title": "XSS Vulnerability in Security Magazine Website",
#     "url": "http://www.cybernewsalerts.com/2014/02/xss-vulnerability-in-security-magazine.html"
# }
# {
#     "author": "dang",
#     "createdAt": "2014-04-21T00:01:00Z",
#     "numComments": 195,
#     "objectId": "7618971",
#     "points": 141,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_dang",
#         "story_7618971"
#     ],
#     "title": "Capital Man: Thomas Piketty is economics\u2019 biggest sensation and fiercest critic",
#     "url": "http://chronicle.com/article/Capital-Man/146059"
# }
# {
#     "author": "danso",
#     "createdAt": "2014-01-07T23:59:38Z",
#     "numComments": 0,
#     "objectId": "7020866",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_danso",
#         "story_7020866"
#     ],
#     "title": "When Doctors \u2018Google\u2019 Their Patients",
#     "url": "http://well.blogs.nytimes.com/2014/01/06/when-doctors-google-their-patients-2/?ref=health"
# }
# {
#     "author": "davidkellis",
#     "createdAt": "2014-05-19T14:10:05Z",
#     "numComments": 0,
#     "objectId": "7767471",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_davidkellis",
#         "story_7767471"
#     ],
#     "title": "A More Elegant View of the Correlation Coefficient",
#     "url": "http://www.the-idea-shop.com/article/221/a-more-elegant-view-of-the-correlation-coefficient"
# }
# {
#     "author": "decentrality",
#     "createdAt": "2014-03-15T13:09:46Z",
#     "numComments": 1,
#     "objectId": "7404522",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_decentrality",
#         "story_7404522"
#     ],
#     "title": "Religion Is Good For Your Brain",
#     "url": "http://science.slashdot.org/story/14/03/15/0542248/religion-is-good-for-your-brain"
# }
# {
#     "author": "dfjorque",
#     "createdAt": "2014-02-18T12:49:36Z",
#     "numComments": 15,
#     "objectId": "7257815",
#     "points": 42,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_dfjorque",
#         "story_7257815"
#     ],
#     "title": "Acid-bath stem-cell study under investigation",
#     "url": "http://www.nature.com/news/acid-bath-stem-cell-study-under-investigation-1.14738"
# }
# {
#     "author": "djstyle",
#     "createdAt": "2014-05-06T00:18:57Z",
#     "numComments": 0,
#     "objectId": "7702159",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_djstyle",
#         "story_7702159"
#     ],
#     "title": "Most Shared/Viewed Tech Articles 5/4~5/5",
#     "url": "https://www.underline.io/most/list"
# }
# {
#     "author": "dougk16",
#     "createdAt": "2014-01-08T19:45:56Z",
#     "numComments": 6,
#     "objectId": "7026009",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_dougk16",
#         "story_7026009",
#         "show_hn"
#     ],
#     "title": "Show HN: New take on my resume.",
#     "url": "http://www.dougkoellmer.com/resume/"
# }
# {
#     "author": "dstanden",
#     "createdAt": "2014-05-19T21:01:24Z",
#     "numComments": 0,
#     "objectId": "7769715",
#     "points": 3,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_dstanden",
#         "story_7769715"
#     ],
#     "title": "Dating App Loveflutter Reboots As A More \u201cQuirky\u201d Tinder",
#     "url": "http://techcrunch.com/2014/05/19/fluttery-will-get-you-everywhere/"
# }
# {
#     "author": "edent",
#     "createdAt": "2014-01-10T11:52:32Z",
#     "numComments": 66,
#     "objectId": "7036181",
#     "points": 148,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_edent",
#         "story_7036181"
#     ],
#     "title": "Malicious Use of the HTML5 Vibrate API",
#     "url": "http://shkspr.mobi/blog/2014/01/malicious-use-of-the-html5-vibrate-api/"
# }
# {
#     "author": "eldadzz",
#     "createdAt": "2014-01-28T15:46:46Z",
#     "numComments": 0,
#     "objectId": "7137706",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_eldadzz",
#         "story_7137706"
#     ],
#     "title": "Exclusive interview with Olivier Amar, founder of award winning MyPermissions",
#     "url": "http://podcasts.startupcamel.com/SC_010-Olivier_Amar-MyPermissions.mp3?utm_source=hackernews&utm_medium=post&utm_campaign=episode_010"
# }
# {
#     "author": "eplanit",
#     "createdAt": "2014-04-01T22:14:01Z",
#     "numComments": 0,
#     "objectId": "7512114",
#     "points": 1,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_eplanit",
#         "story_7512114"
#     ],
#     "title": "SQL Injection Vuln Disclosure by Oculus VR",
#     "url": "http://us5.campaign-archive1.com/?u=88dbd06829e35d5cbf84bbc2e&id=dbf8e7748c&e=6dee15b862"
# }
# {
#     "author": "evanvanness",
#     "createdAt": "2014-04-25T13:47:27Z",
#     "numComments": 0,
#     "objectId": "7646383",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_evanvanness",
#         "story_7646383"
#     ],
#     "title": "How a poker player with no experience snagged a job interview with Mike Moritz",
#     "url": "http://www.businessinsider.com/thomas-page-interview-michael-moritz-2014-4"
# }
# {
#     "author": "fh973",
#     "createdAt": "2014-03-10T20:34:42Z",
#     "numComments": 60,
#     "objectId": "7375522",
#     "points": 67,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_fh973",
#         "story_7375522"
#     ],
#     "title": "Kimsufi: the affordable dedicated server",
#     "url": "https://www.kimsufi.com/en/"
# }
# {
#     "author": "fortepianissimo",
#     "createdAt": "2014-02-20T15:03:13Z",
#     "numComments": 0,
#     "objectId": "7271035",
#     "points": 7,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_fortepianissimo",
#         "story_7271035"
#     ],
#     "title": "The Math That Predicted the Revolutions Sweeping the Globe Right Now",
#     "url": "http://motherboard.vice.com/blog/a-complex-systems-model-predicted-the-revolutions-sweeping-the-globe-right"
# }
# {
#     "author": "fun2have",
#     "createdAt": "2014-04-03T09:45:16Z",
#     "numComments": 0,
#     "objectId": "7521809",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_fun2have",
#         "story_7521809"
#     ],
#     "title": "Precision Navigation and tackling aircraft noise",
#     "url": "http://nats.aero/blog/2014/04/precision-navigation-tackling-aircraft-noise/"
# }
# {
#     "author": "geekfactor",
#     "createdAt": "2014-04-13T00:29:33Z",
#     "numComments": 5,
#     "objectId": "7579697",
#     "points": 9,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_geekfactor",
#         "story_7579697"
#     ],
#     "title": "How Lending A Friend Your Car Before Going to Bed Can Land You Life in Prison",
#     "url": "http://www.thenation.com/article/178984/why-florida-man-facing-life-prison-lending-out-his-car-and-going-sleep"
# }
# {
#     "author": "ghosh",
#     "createdAt": "2014-03-11T17:11:43Z",
#     "numComments": 11,
#     "objectId": "7380637",
#     "points": 33,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_ghosh",
#         "story_7380637"
#     ],
#     "title": "Attackers trick 162,000 WordPress sites into launching DDoS attack ",
#     "url": "http://arstechnica.com/security/2014/03/more-than-162000-legit-wordpress-sites-abused-in-powerful-ddos-attack/"
# }
# {
#     "author": "glaugh",
#     "createdAt": "2014-05-08T18:07:10Z",
#     "numComments": 1,
#     "objectId": "7716698",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_glaugh",
#         "story_7716698"
#     ],
#     "title": "Results of HN poll: Half think bootcamp grads as good as fresh CS Majors",
#     "url": "http://blog.statwing.com/results-of-hn-poll-half-think-bootcamp-grads-as-good-as-fresh-cs-majors/"
# }
# {
#     "author": "gregcohn",
#     "createdAt": "2014-05-16T04:39:31Z",
#     "numComments": 0,
#     "objectId": "7753769",
#     "points": 1,
#     "storyText": "We&#x27;re on the buy side of a real estate transaction right now (actually, several, if you count various auctions we&#x27;ve been in and an escrow we dropped out of).  Some good friends of ours are on the sell side right now.<p>We&#x27;re both finding similar issues -- in our market at least, the convention seems to be that sellers set lower-than-market listing prices, leading to multiple-bid situations with competition on both price and terms (such as size of down payment and whether there are appraisal and inspection contingencies), and then realtors who optimize for the transaction closing rather than the getting the best terms for their clients.<p>What is the best way to play from either buy or sell side in your view?",
#     "tags": [
#         "story",
#         "author_gregcohn",
#         "story_7753769",
#         "ask_hn"
#     ],
#     "title": "Ask HN: Optimal negotiating strategy for real estate purchases",
#     "url": ""
# }
# {
#     "author": "gwern",
#     "createdAt": "2014-02-28T20:44:48Z",
#     "numComments": 0,
#     "objectId": "7321363",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_gwern",
#         "story_7321363"
#     ],
#     "title": "Of Mice [Studies] and Men",
#     "url": "http://pipeline.corante.com/archives/2013/11/26/of_mice_studies_and_men.php"
# }
# {
#     "author": "hashx",
#     "createdAt": "2014-03-22T16:46:56Z",
#     "numComments": 0,
#     "objectId": "7449769",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_hashx",
#         "story_7449769"
#     ],
#     "title": "Best",
#     "url": "https://news.ycombinator.com/best"
# }
# {
#     "author": "hhimanshu",
#     "createdAt": "2014-04-19T18:50:02Z",
#     "numComments": 0,
#     "objectId": "7614294",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_hhimanshu",
#         "story_7614294"
#     ],
#     "title": "Twitter Bootstrap is Down?",
#     "url": "http://getbootstrap.com/"
# }
# {
#     "author": "huntleydavis",
#     "createdAt": "2014-04-01T14:18:39Z",
#     "numComments": 0,
#     "objectId": "7508319",
#     "points": 1,
#     "storyText": "As many of you know, we have been neck and neck with a competing cleaning company and recently things have gotten very tense as we battle for market share and cleaners.  Well, that tension can die down now and we can relax a little bit because Homejoy has decided to acquire our largest competitor : Dogejoy . While, we all felt that Homejoy would eventually win the home cleaning race, something about Dogejoy&#x27;s cute fuzzy faces and broken english made us a little nervous.",
#     "tags": [
#         "story",
#         "author_huntleydavis",
#         "story_7508319"
#     ],
#     "title": "Homejoy acquires largest competitor",
#     "url": "http://www.dogejoy.com"
# }
# {
#     "author": "ibsathish",
#     "createdAt": "2014-01-28T10:48:11Z",
#     "numComments": 0,
#     "objectId": "7136377",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_ibsathish",
#         "story_7136377"
#     ],
#     "title": "Did Big Internet Companies Handicap Startups in FISA Rule Changes?",
#     "url": "http://bits.blogs.nytimes.com/2014/01/27/did-big-internet-companies-handicap-start-ups-in-fisa-rule-changes/?_php=true&_type=blogs&module=BlogPost-Title&version=Blog%20Main&contentCollection=Technology&action=Click&pgtype=Blogs&region=Body&_r=0"
# }
# {
#     "author": "infosecbuzz",
#     "createdAt": "2014-05-02T09:25:32Z",
#     "numComments": 0,
#     "objectId": "7684737",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_infosecbuzz",
#         "story_7684737"
#     ],
#     "title": "Do I Need an Identity API",
#     "url": "http://blog.identropy.com/IAM-blog/bid/109741/Do-I-Need-an-Identity-API-Part-1-of-3"
# }
# {
#     "author": "ivanca",
#     "createdAt": "2014-03-17T21:56:08Z",
#     "numComments": 0,
#     "objectId": "7418382",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_ivanca",
#         "story_7418382"
#     ],
#     "title": "Tetris++",
#     "url": "http://cutcss.com/tetris++/"
# }
# {
#     "author": "jamesbritt",
#     "createdAt": "2014-03-18T16:05:27Z",
#     "numComments": 0,
#     "objectId": "7422715",
#     "points": 4,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_jamesbritt",
#         "story_7422715"
#     ],
#     "title": "Robot writes LA Times earthquake breaking news article",
#     "url": "http://www.bbc.com/news/technology-26614051"
# }
# {
#     "author": "javinpaul",
#     "createdAt": "2014-02-21T16:20:24Z",
#     "numComments": 0,
#     "objectId": "7277630",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_javinpaul",
#         "story_7277630"
#     ],
#     "title": "Apache Tomcat 7.0.52 released Fix CVE-2014-0050",
#     "url": "http://mail-archives.apache.org/mod_mbox/www-announce/201402.mbox/%3CCAFmzfTUQY382p6uVLF4w2MMt7fMJC7TTrTdaKRn%2BzMF8pYroQg%40mail.gmail.com%3E"
# }
# {
#     "author": "jdmitch",
#     "createdAt": "2014-03-25T03:22:06Z",
#     "numComments": 0,
#     "objectId": "7463609",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_jdmitch",
#         "story_7463609"
#     ],
#     "title": "Emil Krebs",
#     "url": "https://en.wikipedia.org/wiki/Emil_Krebs"
# }
# {
#     "author": "jetienne2",
#     "createdAt": "2014-04-29T11:55:00Z",
#     "numComments": 0,
#     "objectId": "7666315",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_jetienne2",
#         "story_7666315"
#     ],
#     "title": "Beautiful Dynamic Laser Beams for Your THREE.js Space Game with threex.laser ",
#     "url": "http://learningthreejs.com/blog/2014/04/29/beautiful-dynamic-laser-beams-for-your-space-game-with-threex-dot-laser-game-extension-for-three-dot-js/"
# }
# {
#     "author": "jkol36",
#     "createdAt": "2014-03-05T15:44:24Z",
#     "numComments": 5,
#     "objectId": "7347573",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_jkol36",
#         "story_7347573"
#     ],
#     "title": "A cool use of the Twitter API",
#     "url": "http://www.flockwith.me"
# }
# {
#     "author": "joemcgonegal",
#     "createdAt": "2014-01-03T12:51:37Z",
#     "numComments": 0,
#     "objectId": "7005178",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_joemcgonegal",
#         "story_7005178"
#     ],
#     "title": "How three MIT alums are changing the NBA as we know it.",
#     "url": "http://alum.mit.edu/pages/sliceofmit/2014/01/03/the-nba-national-big-data-association/"
# }
# {
#     "author": "jonmarkgo",
#     "createdAt": "2014-05-18T20:35:39Z",
#     "numComments": 0,
#     "objectId": "7764321",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_jonmarkgo",
#         "story_7764321"
#     ],
#     "title": "AT&T In Talks to Acquire DirecTV",
#     "url": "http://dealbook.nytimes.com/2014/05/12/att-said-to-be-in-talks-for-directv/?_php=true&_type=blogs&_r=0"
# }
# {
#     "author": "jphaas",
#     "createdAt": "2014-04-09T21:32:23Z",
#     "numComments": 0,
#     "objectId": "7562597",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_jphaas",
#         "story_7562597"
#     ],
#     "title": "How I built in app in 30 minutes using Bubble",
#     "url": "http://make.bubble.is/post/82137936513/how-i-built-an-app-in-30-minutes-using-bubble"
# }
# {
#     "author": "juliennakache",
#     "createdAt": "2014-01-08T04:03:43Z",
#     "numComments": 0,
#     "objectId": "7021604",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_juliennakache",
#         "story_7021604"
#     ],
#     "title": "Oscar Insurance just raised another $30M. Come work with US :)",
#     "url": "http://dealbook.nytimes.com/2014/01/07/oscar-a-new-health-insurer-raises-30-million/"
# }
# {
#     "author": "kamaal",
#     "createdAt": "2014-01-08T06:00:50Z",
#     "numComments": 0,
#     "objectId": "7021975",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_kamaal",
#         "story_7021975"
#     ],
#     "title": "WaterWheel to ease burden on women",
#     "url": "http://www.theguardian.com/global-development/poverty-matters/2013/dec/29/waterwheel-burden-women-water-container"
# }
# {
#     "author": "kercker",
#     "createdAt": "2014-05-20T11:20:36Z",
#     "numComments": 0,
#     "objectId": "7771994",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_kercker",
#         "story_7771994"
#     ],
#     "title": "China Central Government: ban on Windows 8 powered computer systems",
#     "url": "http://translate.google.com/translate?hl=en&sl=zh-CN&tl=en&u=http%3A%2F%2Fwww.ccgp.gov.cn%2Fzycg%2Fzycgdt%2F201405%2Ft20140520_3462564.shtml"
# }
# {
#     "author": "kjhughes",
#     "createdAt": "2014-01-17T02:58:13Z",
#     "numComments": 79,
#     "objectId": "7074019",
#     "points": 54,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_kjhughes",
#         "story_7074019"
#     ],
#     "title": "California woman who drove with Google Glass beats traffic ticket",
#     "url": "http://www.reuters.com/article/2014/01/17/us-usa-googleglass-trial-dismissal-idUSBREA0F1XR20140117"
# }
# {
#     "author": "krg",
#     "createdAt": "2014-05-12T22:18:15Z",
#     "numComments": 0,
#     "objectId": "7735719",
#     "points": 4,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_krg",
#         "story_7735719"
#     ],
#     "title": "FreedomBox-0.2",
#     "url": "http://www.freedomboxfoundation.org/news/FreedomBox-0.2/index.en.html"
# }
# {
#     "author": "kylemathews",
#     "createdAt": "2014-02-08T06:38:15Z",
#     "numComments": 0,
#     "objectId": "7200513",
#     "points": 3,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_kylemathews",
#         "story_7200513"
#     ],
#     "title": "Jumpers and the Software Defined Localhost",
#     "url": "https://coreos.com/blog/Jumpers-and-the-software-defined-localhost/"
# }
# {
#     "author": "lelf",
#     "createdAt": "2014-04-21T23:24:15Z",
#     "numComments": 0,
#     "objectId": "7624675",
#     "points": 2,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_lelf",
#         "story_7624675"
#     ],
#     "title": "R3: Announcing the next generation of Amazon EC2 Memory-optimized instances",
#     "url": "http://aws.amazon.com/about-aws/whats-new/2014/04/10/r3-announcing-the-next-generation-of-amazon-ec2-memory-optimized-instances/"
# }
# {
#     "author": "liam_boogar",
#     "createdAt": "2014-04-28T08:21:17Z",
#     "numComments": 0,
#     "objectId": "7658801",
#     "points": 1,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_liam_boogar",
#         "story_7658801"
#     ],
#     "title": "Argus Labs raises $1.5 Million to bring Emotional Context to Mobile AdTech",
#     "url": "http://www.rudebaguette.com/2014/04/28/belgiums-argus-labs-raises-1-5-million-build-white-label-brain-connected-hardware/"
# }
# {
#     "author": "lockhart",
#     "createdAt": "2014-02-21T16:17:03Z",
#     "numComments": 1,
#     "objectId": "7277616",
#     "points": 1,
#     "storyText": "Frustrated by NBC&#x27;s inability to offer a package to those of us who have long ago cut cable, but still want to catch the Olympics (or just today&#x27;s hockey game)?<p>ZenMate, a web proxy&#x2F;encryption service has a free trial going on. Install the Chrome extension. Set your location to Great Britain and then head over to the BBC site where you&#x27;ll be able to stream to your heart&#x27;s content.<p>Note: The British play-by-play for the hockey games is hysterical.",
#     "tags": [
#         "story",
#         "author_lockhart",
#         "story_7277616"
#     ],
#     "title": "Access the BBC stream of the Olympics ",
#     "url": ""
# }
# {
#     "author": "lushlifemedia",
#     "createdAt": "2014-01-22T17:50:56Z",
#     "numComments": 0,
#     "objectId": "7104179",
#     "points": 3,
#     "storyText": "Docker open source containers are taking the hosting world by storm. Connectify has analyzed how Docker changes the hosting game, and fundamentally reduces the value of Amazon EC2. Others seem to agree, as investors just gave Docker $15M to to expand support for the technology. http:&#x2F;&#x2F;www.connectify.me&#x2F;better-switchboard-docker&#x2F;",
#     "tags": [
#         "story",
#         "author_lushlifemedia",
#         "story_7104179"
#     ],
#     "title": "How Connectify is Using Docker to Build its Switchboard Cloud",
#     "url": ""
# }
# {
#     "author": "madhukarah",
#     "createdAt": "2014-03-16T10:05:08Z",
#     "numComments": 0,
#     "objectId": "7408858",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_madhukarah",
#         "story_7408858"
#     ],
#     "title": "How entrepreneurs deal with negative feedback",
#     "url": "http://thenextweb.com/boris/2014/03/16/entrepreneurs-deal-negative-feedback/"
# }
# {
#     "author": "marcusataylor",
#     "createdAt": "2014-04-01T11:54:59Z",
#     "numComments": 0,
#     "objectId": "7507409",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_marcusataylor",
#         "story_7507409"
#     ],
#     "title": "How six well-known blogs grew to millions of visitors in under 2 years",
#     "url": "http://www.ventureharbour.com/6-popular-blogs-grew-millions-visitors-less-2-years/"
# }
# {
#     "author": "mathattack",
#     "createdAt": "2014-04-04T18:17:48Z",
#     "numComments": 0,
#     "objectId": "7533277",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_mathattack",
#         "story_7533277"
#     ],
#     "title": "Why I rank my friends",
#     "url": "http://kernelmag.dailydot.com/comment/column/9497/why-i-rank-my-friends-by-income-iq-and-hotness/?curator=MediaREDEF#"
# }
# {
#     "author": "mboses",
#     "createdAt": "2014-02-24T19:27:44Z",
#     "numComments": 0,
#     "objectId": "7292842",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_mboses",
#         "story_7292842"
#     ],
#     "title": "Watch the Samsung Unpacked event live",
#     "url": "http://guru8.net/2014/02/samsungunpacked/"
# }
# {
#     "author": "mfincham",
#     "createdAt": "2014-01-07T03:29:42Z",
#     "numComments": 0,
#     "objectId": "7015213",
#     "points": 3,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_mfincham",
#         "story_7015213"
#     ],
#     "title": "Emergency Self Destruction of LUKS in Kali",
#     "url": "http://www.kali.org/how-to/emergency-self-destruction-luks-kali/"
# }
# {
#     "author": "miguelindurain",
#     "createdAt": "2014-03-05T09:15:04Z",
#     "numComments": 0,
#     "objectId": "7346097",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_miguelindurain",
#         "story_7346097"
#     ],
#     "title": "From a Venezuelan academic",
#     "url": "http://pastebin.com/vL1ntqTH"
# }
# {
#     "author": "mjadobson",
#     "createdAt": "2014-02-09T20:28:22Z",
#     "numComments": 4,
#     "objectId": "7207060",
#     "points": 6,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_mjadobson",
#         "story_7207060"
#     ],
#     "title": "Draggable Physics Animation Demo",
#     "url": "https://www.greensock.com/draggable/"
# }
# {
#     "author": "moreati",
#     "createdAt": "2014-02-03T18:59:21Z",
#     "numComments": 0,
#     "objectId": "7172705",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_moreati",
#         "story_7172705"
#     ],
#     "title": "Hold the Hamburger",
#     "url": "http://blog.isotoma.com/2014/02/hold-the-hamburger/"
# }
# {
#     "author": "msemenistyi",
#     "createdAt": "2014-02-18T09:36:10Z",
#     "numComments": 0,
#     "objectId": "7257207",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_msemenistyi",
#         "story_7257207"
#     ],
#     "title": "Tool for managing events in JavaScript",
#     "url": "https://github.com/msemenistyi/capo"
# }
# {
#     "author": "nader",
#     "createdAt": "2014-02-10T01:05:48Z",
#     "numComments": 0,
#     "objectId": "7208435",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_nader",
#         "story_7208435"
#     ],
#     "title": "Quiet And Distraction-Free. When I Forgot My Phone Charger.",
#     "url": "http://bondero.com/distraction-free-phone"
# }
# {
#     "author": "nealabq",
#     "createdAt": "2014-01-01T18:41:10Z",
#     "numComments": 0,
#     "objectId": "6995914",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_nealabq",
#         "story_6995914"
#     ],
#     "title": "Nailing down climate uncertainty hints at greater future warming",
#     "url": "http://arstechnica.com/science/2014/01/nailing-down-climate-uncertainty-hints-at-greater-future-warming/"
# }
# {
#     "author": "nickbauman",
#     "createdAt": "2014-01-15T23:19:53Z",
#     "numComments": 1,
#     "objectId": "7066948",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_nickbauman",
#         "story_7066948"
#     ],
#     "title": "Net Losses: James Surowiecki on Net Neutrality (2006)",
#     "url": "http://www.newyorker.com/archive/2006/03/20/060320ta_talk_surowiecki"
# }
# {
#     "author": "nkurz",
#     "createdAt": "2014-04-16T18:46:25Z",
#     "numComments": 1,
#     "objectId": "7599680",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_nkurz",
#         "story_7599680"
#     ],
#     "title": "Solve your problem by almost asking a question on StackOverflow",
#     "url": "http://blog.jerryorr.com/2014/04/solve-your-problem-by-almost-asking.html"
# }
# {
#     "author": "nreece",
#     "createdAt": "2014-03-12T22:40:52Z",
#     "numComments": 0,
#     "objectId": "7388905",
#     "points": 2,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_nreece",
#         "story_7388905"
#     ],
#     "title": "The Algorithm Economy: Inside the Formulas of Facebook and Amazon",
#     "url": "http://www.theatlantic.com/business/archive/2014/03/the-algorithm-economy-inside-the-formulas-of-facebook-and-amazon/284358/"
# }
# {
#     "author": "ojbyrne",
#     "createdAt": "2014-05-27T04:52:59Z",
#     "numComments": 0,
#     "objectId": "7802925",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_ojbyrne",
#         "story_7802925"
#     ],
#     "title": "When Hiring Employees, Look For A Track Record Of Failures, Not Successes",
#     "url": "http://www.forbes.com/sites/sungardas/2014/05/12/when-hiring-employees-look-for-a-track-record-of-failures-not-successes/"
# }
# {
#     "author": "ossamaben",
#     "createdAt": "2014-01-29T14:03:30Z",
#     "numComments": 0,
#     "objectId": "7143827",
#     "points": 1,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_ossamaben",
#         "story_7143827"
#     ],
#     "title": "How Does James Altucher Blog So Consistently ",
#     "url": "http://www.followletter.com/publication/1372-how-does-james-altucher-blog-so-consistently#.UukKKOkFQKo.hackernews"
# }
# {
#     "author": "parassidisv",
#     "createdAt": "2014-03-01T03:29:47Z",
#     "numComments": 0,
#     "objectId": "7322986",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_parassidisv",
#         "story_7322986"
#     ],
#     "title": "The Peculiar Decimal System and the Naming Question [pdf]",
#     "url": "http://www3.telus.net/public/gaye_s/Decimal.pdf"
# }
# {
#     "author": "periferral",
#     "createdAt": "2014-05-20T16:44:30Z",
#     "numComments": 0,
#     "objectId": "7773554",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_periferral",
#         "story_7773554"
#     ],
#     "title": "12\" Surface Pro 3 \u2013 $799",
#     "url": "http://www.engadget.com/2014/05/20/microsoft-surface-pro-3/"
# }
# {
#     "author": "phiggy",
#     "createdAt": "2014-01-02T19:54:24Z",
#     "numComments": 14,
#     "objectId": "7001819",
#     "points": 66,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_phiggy",
#         "story_7001819"
#     ],
#     "title": "Distributed systems for fun and profit (free ebook)",
#     "url": "http://book.mixu.net/distsys/"
# }
# {
#     "author": "platz",
#     "createdAt": "2014-03-03T21:49:20Z",
#     "numComments": 0,
#     "objectId": "7336748",
#     "points": 1,
# ...
# }
# {
#     "author": "quantumm",
#     "createdAt": "2014-05-16T11:46:16Z",
#     "numComments": 1,
#     "objectId": "7754965",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_quantumm",
#         "story_7754965"
#     ],
#     "title": "Why Your Personal Brand Matters More Now",
#     "url": "https://www.linkedin.com/today/post/article/20140516062449-2143418-why-your-personal-brand-matters"
# }
# {
#     "author": "rajahafify",
#     "createdAt": "2014-05-03T02:39:21Z",
#     "numComments": 0,
#     "objectId": "7689304",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_rajahafify",
#         "story_7689304"
#     ],
#     "title": "Projek Filem \u2013 GitHub for videomaker \u2013 A crowdfunding campaign.",
#     "url": "http://pitchin.my/project/40"
# }
# {
#     "author": "rdemmer",
#     "createdAt": "2014-03-11T16:22:48Z",
#     "numComments": 0,
#     "objectId": "7380257",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_rdemmer",
#         "story_7380257"
#     ],
#     "title": "JetBrains Newsletter \u2013 March Edition",
#     "url": "http://info.jetbrains.com/rs/jetbrains/images/2014_03_March_JetBrains_Newsletter.html"
# }
# {
#     "author": "rgovind",
#     "createdAt": "2014-04-18T18:38:26Z",
#     "numComments": 0,
#     "objectId": "7610572",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_rgovind",
#         "story_7610572"
#     ],
#     "title": "Google Trends Debuts Email Notifications For Search Topics",
#     "url": "http://techcrunch.com/2014/04/18/google-trends-debuts-email-notifications-for-search-topics-hot-searches-and-more/"
# }
# {
#     "author": "robertlaing",
#     "createdAt": "2014-03-10T08:50:12Z",
#     "numComments": 0,
#     "objectId": "7371875",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_robertlaing",
#         "story_7371875"
#     ],
#     "title": "Life with the Narrative Clip in 20 slides",
#     "url": "http://www.pechakucha.org/presentations/moments-not-photos"
# }
# {
#     "author": "rozag",
#     "createdAt": "2014-04-30T15:24:37Z",
#     "numComments": 0,
#     "objectId": "7673903",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_rozag",
#         "story_7673903"
#     ],
#     "title": "What about some self-improvement?",
#     "url": "https://play.google.com/store/apps/details?id=com.vsrstudio.upgrowth_free"
# }
# {
#     "author": "ryan_twinlabs",
#     "createdAt": "2014-02-24T16:04:34Z",
#     "numComments": 0,
#     "objectId": "7291490",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_ryan_twinlabs",
#         "story_7291490"
#     ],
#     "title": "1 Million Cups Shreveport Launches Feb 26",
#     "url": "http://blog.twinenginelabs.com/2014/02/shreveport-1-million-cups-launches.html"
# }
# {
#     "author": "samymassoud",
#     "createdAt": "2014-02-11T14:08:22Z",
#     "numComments": 1,
#     "objectId": "7217642",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_samymassoud",
#         "story_7217642"
#     ],
#     "title": "Flappy bird is available again for android",
#     "url": "http://zahraanasrcity.com/t/99"
# }
# {
#     "author": "scoates",
#     "createdAt": "2014-02-26T16:15:21Z",
#     "numComments": 0,
#     "objectId": "7305767",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_scoates",
#         "story_7305767"
#     ],
#     "title": "Scenes from an Internet",
#     "url": "https://the-pastry-box-project.net/cameron-koczon/2014-February-26"
# }
# {
#     "author": "semilshah",
#     "createdAt": "2014-01-11T07:11:27Z",
#     "numComments": 0,
#     "objectId": "7041910",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_semilshah",
#         "story_7041910"
#     ],
#     "title": "Some Observations Regarding Big VC, One Year Into Investing",
#     "url": "http://blog.semilshah.com/2014/01/11/some-observations-regarding-big-vc-one-year-into-investing/"
# }
# {
#     "author": "shasa",
#     "createdAt": "2014-01-20T18:04:41Z",
#     "numComments": 0,
#     "objectId": "7090858",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_shasa",
#         "story_7090858"
#     ],
#     "title": "Growth Hacking Pre-Launch Revenue",
#     "url": "http://sixteenventures.com/pre-launch-growth-hacking"
# }
# {
#     "author": "signa11",
#     "createdAt": "2014-02-27T09:20:24Z",
#     "numComments": 0,
#     "objectId": "7311208",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_signa11",
#         "story_7311208"
#     ],
#     "title": "Meet the Dropleton\u2014a \u201cQuantum Droplet\u201d That Acts Like a Liquid",
#     "url": "http://www.scientificamerican.com/article/dropleton-quantum-droplet-quasiparticle/"
# }
# {
#     "author": "sjcsjc",
#     "createdAt": "2014-04-08T19:15:16Z",
#     "numComments": 0,
#     "objectId": "7555337",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_sjcsjc",
#         "story_7555337"
#     ],
#     "title": "Allaire Causes a Stir With Address at Inside Bitcoins Conference",
#     "url": "http://blogs.wsj.com/moneybeat/2014/04/07/bitbeat-allaire-causes-a-stir-with-address-at-inside-bitcoins-conference/"
# }
# {
#     "author": "snowbol",
#     "createdAt": "2014-05-13T20:22:57Z",
#     "numComments": 0,
#     "objectId": "7740469",
#     "points": 1,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_snowbol",
#         "story_7740469"
#     ],
#     "title": "Austin\u2019s Peach Digitally Connects Local Farmers to Restaurant Chefs",
#     "url": "http://www.xconomy.com/texas/2014/05/13/austins-peach-digitally-connects-local-farmers-to-restaurant-chefs/"
# }
# {
#     "author": "spking",
#     "createdAt": "2014-04-18T14:50:03Z",
#     "numComments": 0,
#     "objectId": "7609351",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_spking",
#         "story_7609351"
#     ],
#     "title": "\"How do I get someone to do the coding for free and not give away my idea?\"",
#     "url": "https://clarity.fm/questions/1214/i-have-this-social-media-idea-but-no-coding-skills-how-do-i-get-someone-to-do"
# }
# {
#     "author": "stesch",
#     "createdAt": "2014-05-11T11:27:41Z",
#     "numComments": 0,
#     "objectId": "7728410",
#     "points": 1,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_stesch",
#         "story_7728410"
#     ],
#     "title": "This Week in Science",
#     "url": "http://i.imgur.com/9GWxtj4.png"
# }
# {
#     "author": "sungsoo1094",
#     "createdAt": "2014-04-05T16:40:26Z",
#     "numComments": 3,
#     "objectId": "7537537",
#     "points": 1,
#     "storyText": "Hi, we&#x27;ve been working on an online test prep service called CUVE.\\nWe&#x27;ve done a round of beta testing with &#x27;normal&#x27; users,\\nand here we&#x27;re specifically looking for hackers who can criticize us from user &#x2F; developer &#x2F; investor perspectives.\\nAs a token of appreciation, we&#x27;ll be giving out $10 Amazon gift cards. (via email)<p>Here&#x27;s how it will work:<p>1. Visit our site (www.cuve.me) and give it a try.\\n2. Fill out two surveys (links below), one for general feedback and another one for detailed comments.\\n3. We&#x27;ll give gift cards to the first five hackers who fill out the survey. (all five)\\n4. We&#x27;ll give out five more to the rest of hackers. (random select)\\n5. We&#x27;ll determine the first five by the order of registered comments so please declare your participation in comments before you begin.\\n6. Make sure to put your hacker news ID and email on the survey so we can correctly send out the gift cards.<p>We&#x27;re a very early stage startup, so the budget is extremely limited.\\nAlthough it&#x27;s only a $10 gift card, we&#x27;d really appreciate if you could help us with detailed, critical comments.<p>Thanks for the help!!!<p>General Survey: www.surveymonkey.com&#x2F;s&#x2F;7W7HXDH\\nDetailed Survey: www.surveymonkey.com&#x2F;s&#x2F;7ZF9RLY",
#     "tags": [
#         "story",
#         "author_sungsoo1094",
#         "story_7537537",
#         "ask_hn"
#     ],
#     "title": "Ask HN: how critical can you be for a $10 Amazon gift card?",
#     "url": ""
# }
# {
#     "author": "szimpl",
#     "createdAt": "2014-01-23T15:13:26Z",
#     "numComments": 0,
#     "objectId": "7108605",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_szimpl",
#         "story_7108605"
#     ],
#     "title": "How to learn more in 2014",
#     "url": "http://www.webdesignerdepot.com/2014/01/how-to-learn-more-in-2014/"
# }
# {
#     "author": "taylorbuley",
#     "createdAt": "2014-03-13T15:13:52Z",
#     "numComments": 1,
#     "objectId": "7392315",
#     "points": 12,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_taylorbuley",
#         "story_7392315"
#     ],
#     "title": "WhatsApp database dumper for Metasploit",
#     "url": "https://github.com/rapid7/metasploit-framework/pull/3039"
# }
# {
#     "author": "terhechte",
#     "createdAt": "2014-01-22T16:49:16Z",
#     "numComments": 0,
#     "objectId": "7103742",
#     "points": 3,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_terhechte",
#         "story_7103742",
#         "show_hn"
#     ],
#     "title": "Show HN: Clojure/Enlive Static Site Generator that keeps your HTML intact",
#     "url": "http://appventure.me/2014/01/22/clojure-enlive-static-site-generator-that-keeps-html-intact/"
# }
# {
#     "author": "thepose",
#     "createdAt": "2014-04-21T02:43:45Z",
#     "numComments": 0,
#     "objectId": "7619490",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_thepose",
#         "story_7619490"
#     ],
#     "title": "How to write node programs with streams",
#     "url": "https://github.com/substack/stream-handbook"
# }
# {
#     "author": "tim_sw",
#     "createdAt": "2014-04-08T20:33:19Z",
#     "numComments": 68,
#     "objectId": "7555824",
#     "points": 51,
#     "storyText": "for BRK&#x27;s annual shareholder meeting",
#     "tags": [
#         "story",
#         "author_tim_sw",
#         "story_7555824"
#     ],
#     "title": "Buffett Will Steer Investors to Airbnb to Avoid Price-Gouging by Omaha Hotels",
#     "url": "http://blogs.wsj.com/moneybeat/2014/04/08/buffett-will-steer-investors-to-airbnb-to-avoid-price-gouging-by-omaha-hotels/?mod=yahoo_hs"
# }
# {
#     "author": "tokenadult",
#     "createdAt": "2014-05-03T11:33:39Z",
#     "numComments": 0,
#     "objectId": "7690377",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_tokenadult",
#         "story_7690377"
#     ],
#     "title": "Putin's Next Invasion? The Russian Web",
#     "url": "http://www.businessweek.com/articles/2014-05-01/russia-moves-toward-china-style-internet-censorship"
# }
# {
#     "author": "trendspotter",
#     "createdAt": "2014-03-04T17:36:13Z",
#     "numComments": 36,
#     "objectId": "7341660",
#     "points": 58,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_trendspotter",
#         "story_7341660"
#     ],
#     "title": "Japan to regulate Bitcoin trades, impose taxes",
#     "url": "http://asia.nikkei.com/Politics-Economy/Policy-Politics/Japan-to-regulate-Bitcoin-trades-impose-taxes"
# }
# {
#     "author": "turoczy",
#     "createdAt": "2014-05-28T20:47:02Z",
#     "numComments": 0,
#     "objectId": "7812786",
#     "points": 1,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_turoczy",
#         "story_7812786"
#     ],
#     "title": "Apple purchases Beats Electronics for $3 billion",
#     "url": "http://www.bostonglobe.com/business/2014/05/28/apple-purchases-beats-electronics-for-billion/sPtrl3BrThL4rfVbzXk3mI/story.html"
# }
# {
#     "author": "uladzislau",
#     "createdAt": "2014-02-02T02:58:20Z",
#     "numComments": 0,
#     "objectId": "7164598",
#     "points": 2,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_uladzislau",
#         "story_7164598"
#     ],
#     "title": "NullCrew claims to have hacked Bell Canada",
#     "url": "http://www.databreaches.net/nullcrew-claims-to-have-hacked-bell-canada/"
# }
# {
#     "author": "valtsu",
#     "createdAt": "2014-05-07T18:33:49Z",
#     "numComments": 0,
#     "objectId": "7711896",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_valtsu",
#         "story_7711896"
#     ],
#     "title": "Best problem solvers in the world? Watch them race live.",
#     "url": "https://helloworldopen.com/competition/qualification/R2/4"
# }
# {
#     "author": "vinnyglennon",
#     "createdAt": "2014-04-23T10:18:30Z",
#     "numComments": 0,
#     "objectId": "7633100",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_vinnyglennon",
#         "story_7633100"
#     ],
#     "title": "Practical Advice for Raising Early Stage Venture Capital",
#     "url": "http://webcache.googleusercontent.com/search?q=cache:x9Xd1k005s8J:blogs.hbr.org/2012/09/practical-advice-for-raising-e/+&cd=1&hl=en&ct=clnk&gl=ie"
# }
# {
#     "author": "wallflower",
#     "createdAt": "2014-05-25T16:51:28Z",
#     "numComments": 1,
#     "objectId": "7796763",
#     "points": 2,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_wallflower",
#         "story_7796763"
#     ],
#     "title": "The Shawshank Residuals",
#     "url": "http://online.wsj.com/article/SB10001424052702304536104579560021265554240.html"
# }
# {
#     "author": "wglb",
#     "createdAt": "2014-02-25T01:03:00Z",
#     "numComments": 0,
#     "objectId": "7294491",
#     "points": 1,
#     "storyText": null,
#     "tags": [
#         "story",
#         "author_wglb",
#         "story_7294491"
#     ],
#     "title": "U.S. freezes assets of work-at-home Web firms promising thousands ",
#     "url": "http://www.chicagotribune.com/business/sns-rt-us-ftc-lawsuit-internetcoaches-20140224,0,419753.story"
# }
# {
#     "author": "wodlander",
#     "createdAt": "2014-03-26T12:17:20Z",
#     "numComments": 0,
#     "objectId": "7472855",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_wodlander",
#         "story_7472855"
#     ],
#     "title": "Examples of unconventional growth strategies by popular startups",
#     "url": "http://greyhatter.com/blog/unconventional-growth-strategies-examples"
# }
# {
#     "author": "xendo",
#     "createdAt": "2014-02-22T21:18:11Z",
#     "numComments": 1,
#     "objectId": "7283649",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_xendo",
#         "story_7283649"
#     ],
#     "title": "The Pirate Bay down, again.",
#     "url": "http://thepiratebay.se/"
# }
# {
#     "author": "ycmike",
#     "createdAt": "2014-01-22T18:40:32Z",
#     "numComments": 0,
#     "objectId": "7104485",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_ycmike",
#         "story_7104485"
#     ],
#     "title": "Nerds Got Their Sh*t Together",
#     "url": "http://blog.mikeadeleke.com/nerds-got-their-sh-star-t-together"
# }
# {
#     "author": "yodaiken",
#     "createdAt": "2014-05-07T22:58:27Z",
#     "numComments": 4,
#     "objectId": "7713092",
#     "points": 19,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_yodaiken",
#         "story_7713092",
#         "show_hn"
#     ],
#     "title": "Show HN: Fight for Net Neutrality with slowlane.js",
#     "url": "https://github.com/yodaiken/slowlane/"
# }
# {
#     "author": "zaporozhets",
#     "createdAt": "2014-02-04T07:11:59Z",
#     "numComments": 0,
#     "objectId": "7175925",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_zaporozhets",
#         "story_7175925"
#     ],
#     "title": "HTML5 History the easy way.",
#     "url": "http://michaelzaporozhets.github.io/simpler-history/"
# }
# {
#     "author": "zubairov",
#     "createdAt": "2014-04-24T08:14:22Z",
#     "numComments": 0,
#     "objectId": "7638969",
#     "points": 1,
#     "storyText": "",
#     "tags": [
#         "story",
#         "author_zubairov",
#         "story_7638969"
#     ],
#     "title": " PaaS is a commodity now, what's next?",
#     "url": "http://www.elastic.io/blog/83702475704/paas-is-commodity-now-whats-next"
# }

# %% [markdown]
# Next, calculate the item in our JSON list with the smallest age:
